# %%
import pandas as pd

# %% [markdown]
# ## Tourism data

# %%
inbound = pd.read_csv('./data/API_ST.INT.ARVL_DS2_en_csv_v2_1927083.csv')
outbound = pd.read_csv('./data/API_ST.INT.DPRT_DS2_en_csv_v2_1929304.csv')
expenditures = pd.read_csv('./data/API_ST.INT.XPND.CD_DS2_en_csv_v2_1929314.csv')

# %%
inbound.head()
# Out:
#   Country Name Country Code                             Indicator Name  \
# 0        Aruba          ABW  International tourism, number of arrivals
# 1  Afghanistan          AFG  International tourism, number of arrivals
# 2       Angola          AGO  International tourism, number of arrivals
# 3      Albania          ALB  International tourism, number of arrivals
# 4      Andorra          AND  International tourism, number of arrivals
#
#   Indicator Code  1960  1961  1962  1963  1964  1965  ...       2011  \
# 0    ST.INT.ARVL   NaN   NaN   NaN   NaN   NaN   NaN  ...   869000.0
# 1    ST.INT.ARVL   NaN   NaN   NaN   NaN   NaN   NaN  ...        NaN
# 2    ST.INT.ARVL   NaN   NaN   NaN   NaN   NaN   NaN  ...   481000.0
# 3    ST.INT.ARVL   NaN   NaN   NaN   NaN   NaN   NaN  ...  2469000.0
# 4    ST.INT.ARVL   NaN   NaN   NaN   NaN   NaN   NaN  ...  2242000.0
#
#         2012       2013       2014       2015       2016       2017  \
# ...

# %%
outbound.head()
# Out:
#   Country Name Country Code                               Indicator Name  \
# 0        Aruba          ABW  International tourism, number of departures
# 1  Afghanistan          AFG  International tourism, number of departures
# 2       Angola          AGO  International tourism, number of departures
# 3      Albania          ALB  International tourism, number of departures
# 4      Andorra          AND  International tourism, number of departures
#
#   Indicator Code  1960  1961  1962  1963  1964  1965  ...       2011  \
# 0    ST.INT.DPRT   NaN   NaN   NaN   NaN   NaN   NaN  ...        NaN
# 1    ST.INT.DPRT   NaN   NaN   NaN   NaN   NaN   NaN  ...        NaN
# 2    ST.INT.DPRT   NaN   NaN   NaN   NaN   NaN   NaN  ...        NaN
# 3    ST.INT.DPRT   NaN   NaN   NaN   NaN   NaN   NaN  ...  4120000.0
# 4    ST.INT.DPRT   NaN   NaN   NaN   NaN   NaN   NaN  ...        NaN
#
#         2012       2013       2014       2015       2016       2017  \
# ...

# %%
expenditures.head()
# Out:
#   Country Name Country Code  \
# 0        Aruba          ABW
# 1  Afghanistan          AFG
# 2       Angola          AGO
# 3      Albania          ALB
# 4      Andorra          AND
#
#                                       Indicator Name  Indicator Code  1960  \
# 0  International tourism, expenditures (current US$)  ST.INT.XPND.CD   NaN
# 1  International tourism, expenditures (current US$)  ST.INT.XPND.CD   NaN
# 2  International tourism, expenditures (current US$)  ST.INT.XPND.CD   NaN
# 3  International tourism, expenditures (current US$)  ST.INT.XPND.CD   NaN
# 4  International tourism, expenditures (current US$)  ST.INT.XPND.CD   NaN
#
#    1961  1962  1963  1964  1965  ...          2011          2012  \
# 0   NaN   NaN   NaN   NaN   NaN  ...  2.870000e+08  2.940000e+08
# 1   NaN   NaN   NaN   NaN   NaN  ...  2.550000e+08  1.100000e+08
# 2   NaN   NaN   NaN   NaN   NaN  ...  3.230000e+08  2.880000e+08
# 3   NaN   NaN   NaN   NaN   NaN  ...  1.677000e+09  1.374000e+09
# ...

# %%
inbound.columns
# Out:
# Index(['Country Name', 'Country Code', 'Indicator Name', 'Indicator Code',
#        '1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968',
#        '1969', '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977',
#        '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986',
#        '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995',
#        '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004',
#        '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013',
#        '2014', '2015', '2016', '2017', '2018', '2019', '2020'],
#       dtype='object')

# %%
outbound.columns
# Out:
# Index(['Country Name', 'Country Code', 'Indicator Name', 'Indicator Code',
#        '1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968',
#        '1969', '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977',
#        '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986',
#        '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995',
#        '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004',
#        '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013',
#        '2014', '2015', '2016', '2017', '2018', '2019', '2020'],
#       dtype='object')

# %%
expenditures.columns
# Out:
# Index(['Country Name', 'Country Code', 'Indicator Name', 'Indicator Code',
#        '1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968',
#        '1969', '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977',
#        '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986',
#        '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995',
#        '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004',
#        '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013',
#        '2014', '2015', '2016', '2017', '2018', '2019', '2020'],
#       dtype='object')

# %%
print(len(inbound['Country Name'].unique()))
print(len(outbound['Country Name'].unique()))
print(len(expenditures['Country Name'].unique()))
# Out:
# 264
# 264
# 264

# %% [markdown]
# ### Find NaN values

# %%
# find columns with NaNs
inbound.columns[inbound.isna().any()].tolist()
# Out:
# ['1960',
#  '1961',
#  '1962',
#  '1963',
#  '1964',
#  '1965',
#  '1966',
#  '1967',
#  '1968',
#  '1969',
#  '1970',
#  '1971',
#  '1972',
#  '1973',
#  '1974',
#  '1975',
#  '1976',
#  '1977',
#  '1978',
#  '1979',
#  '1980',
#  '1981',
#  '1982',
#  '1983',
#  '1984',
#  '1985',
#  '1986',
#  '1987',
#  '1988',
#  '1989',
#  '1990',
#  '1991',
#  '1992',
#  '1993',
#  '1994',
#  '1995',
#  '1996',
#  '1997',
#  '1998',
#  '1999',
#  '2000',
#  '2001',
#  '2002',
#  '2003',
#  '2004',
#  '2005',
#  '2006',
#  '2007',
#  '2008',
#  '2009',
#  '2010',
#  '2011',
#  '2012',
#  '2013',
#  '2014',
#  '2015',
#  '2016',
#  '2017',
#  '2018',
#  '2019',
#  '2020']

# %%
outbound.columns[outbound.isna().any()].tolist()
# Out:
# ['1960',
#  '1961',
#  '1962',
#  '1963',
#  '1964',
#  '1965',
#  '1966',
#  '1967',
#  '1968',
#  '1969',
#  '1970',
#  '1971',
#  '1972',
#  '1973',
#  '1974',
#  '1975',
#  '1976',
#  '1977',
#  '1978',
#  '1979',
#  '1980',
#  '1981',
#  '1982',
#  '1983',
#  '1984',
#  '1985',
#  '1986',
#  '1987',
#  '1988',
#  '1989',
#  '1990',
#  '1991',
#  '1992',
#  '1993',
#  '1994',
#  '1995',
#  '1996',
#  '1997',
#  '1998',
#  '1999',
#  '2000',
#  '2001',
#  '2002',
#  '2003',
#  '2004',
#  '2005',
#  '2006',
#  '2007',
#  '2008',
#  '2009',
#  '2010',
#  '2011',
#  '2012',
#  '2013',
#  '2014',
#  '2015',
#  '2016',
#  '2017',
#  '2018',
#  '2019',
#  '2020']

# %%
expenditures.columns[expenditures.isna().any()].tolist()
# Out:
# ['1960',
#  '1961',
#  '1962',
#  '1963',
#  '1964',
#  '1965',
#  '1966',
#  '1967',
#  '1968',
#  '1969',
#  '1970',
#  '1971',
#  '1972',
#  '1973',
#  '1974',
#  '1975',
#  '1976',
#  '1977',
#  '1978',
#  '1979',
#  '1980',
#  '1981',
#  '1982',
#  '1983',
#  '1984',
#  '1985',
#  '1986',
#  '1987',
#  '1988',
#  '1989',
#  '1990',
#  '1991',
#  '1992',
#  '1993',
#  '1994',
#  '1995',
#  '1996',
#  '1997',
#  '1998',
#  '1999',
#  '2000',
#  '2001',
#  '2002',
#  '2003',
#  '2004',
#  '2005',
#  '2006',
#  '2007',
#  '2008',
#  '2009',
#  '2010',
#  '2011',
#  '2012',
#  '2013',
#  '2014',
#  '2015',
#  '2016',
#  '2017',
#  '2018',
#  '2019',
#  '2020']

# %%
# find lines with Nans
print(len(inbound.isnull().any(axis=1)))
print(len(outbound.isnull().any(axis=1)))
print(len(expenditures.isnull().any(axis=1)))
# Out:
# 264
# 264
# 264

# %%
def count_nans(df):
    print('Number of NaNs in years columns')
    for year in range(1960, 2021):
        print(year, ":", df[str(year)].isnull().sum())

# %%
count_nans(inbound)
# Out:
# Number of NaNs in years columns
# 1960 : 264
# 1961 : 264
# 1962 : 264
# 1963 : 264
# 1964 : 264
# 1965 : 264
# 1966 : 264
# 1967 : 264
# 1968 : 264
# 1969 : 264
# 1970 : 264
# 1971 : 264
# 1972 : 264
# 1973 : 264
# 1974 : 264
# 1975 : 264
# 1976 : 264
# 1977 : 264
# 1978 : 264
# 1979 : 264
# 1980 : 264
# 1981 : 264
# 1982 : 264
# 1983 : 264
# 1984 : 264
# 1985 : 264
# 1986 : 264
# 1987 : 264
# 1988 : 264
# 1989 : 264
# 1990 : 264
# 1991 : 264
# 1992 : 264
# 1993 : 264
# 1994 : 264
# 1995 : 48
# 1996 : 43
# 1997 : 42
# 1998 : 39
# 1999 : 40
# 2000 : 36
# 2001 : 36
# 2002 : 38
# 2003 : 38
# 2004 : 38
# 2005 : 31
# 2006 : 28
# 2007 : 23
# 2008 : 23
# 2009 : 23
# 2010 : 21
# 2011 : 22
# 2012 : 23
# 2013 : 25
# 2014 : 26
# 2015 : 25
# 2016 : 28
# 2017 : 37
# 2018 : 54
# 2019 : 264
# 2020 : 264

# %%
count_nans(outbound)
# Out:
# Number of NaNs in years columns
# 1960 : 264
# 1961 : 264
# 1962 : 264
# 1963 : 264
# 1964 : 264
# 1965 : 264
# 1966 : 264
# 1967 : 264
# 1968 : 264
# 1969 : 264
# 1970 : 264
# 1971 : 264
# 1972 : 264
# 1973 : 264
# 1974 : 264
# 1975 : 264
# 1976 : 264
# 1977 : 264
# 1978 : 264
# 1979 : 264
# 1980 : 264
# 1981 : 264
# 1982 : 264
# 1983 : 264
# 1984 : 264
# 1985 : 264
# 1986 : 264
# 1987 : 264
# 1988 : 264
# 1989 : 264
# 1990 : 264
# 1991 : 264
# 1992 : 264
# 1993 : 264
# 1994 : 264
# 1995 : 169
# 1996 : 168
# 1997 : 161
# 1998 : 156
# 1999 : 156
# 2000 : 151
# 2001 : 150
# 2002 : 149
# 2003 : 150
# 2004 : 153
# 2005 : 143
# 2006 : 142
# 2007 : 143
# 2008 : 142
# 2009 : 137
# 2010 : 134
# 2011 : 136
# 2012 : 134
# 2013 : 138
# 2014 : 139
# 2015 : 141
# 2016 : 139
# 2017 : 141
# 2018 : 145
# 2019 : 264
# 2020 : 264

# %%
count_nans(expenditures)
# Out:
# Number of NaNs in years columns
# 1960 : 264
# 1961 : 264
# 1962 : 264
# 1963 : 264
# 1964 : 264
# 1965 : 264
# 1966 : 264
# 1967 : 264
# 1968 : 264
# 1969 : 264
# 1970 : 264
# 1971 : 264
# 1972 : 264
# 1973 : 264
# 1974 : 264
# 1975 : 264
# 1976 : 264
# 1977 : 264
# 1978 : 264
# 1979 : 264
# 1980 : 264
# 1981 : 264
# 1982 : 264
# 1983 : 264
# 1984 : 264
# 1985 : 264
# 1986 : 264
# 1987 : 264
# 1988 : 264
# 1989 : 264
# 1990 : 264
# 1991 : 264
# 1992 : 264
# 1993 : 264
# 1994 : 264
# 1995 : 67
# 1996 : 67
# 1997 : 63
# 1998 : 64
# 1999 : 64
# 2000 : 63
# 2001 : 60
# 2002 : 50
# 2003 : 50
# 2004 : 48
# 2005 : 35
# 2006 : 33
# 2007 : 32
# 2008 : 30
# 2009 : 29
# 2010 : 30
# 2011 : 29
# 2012 : 28
# 2013 : 30
# 2014 : 30
# 2015 : 31
# 2016 : 29
# 2017 : 38
# 2018 : 54
# 2019 : 264
# 2020 : 264

# %% [markdown]
# NaNs for all years < 1995 and 2019, 2020 => drop these columns

# %%
useless_cols = ['1960',
 '1961',
 '1962',
 '1963',
 '1964',
 '1965',
 '1966',
 '1967',
 '1968',
 '1969',
 '1970',
 '1971',
 '1972',
 '1973',
 '1974',
 '1975',
 '1976',
 '1977',
 '1978',
 '1979',
 '1980',
 '1981',
 '1982',
 '1983',
 '1984',
 '1985',
 '1986',
 '1987',
 '1988',
 '1989',
 '1990',
 '1991',
 '1992',
 '1993',
 '1994',
 '2019', 
 '2020', 'Indicator Name', 'Indicator Code']
inbound.drop(useless_cols, axis='columns', inplace=True)
outbound.drop(useless_cols, axis='columns', inplace=True)
expenditures.drop(useless_cols, axis='columns', inplace=True)

# %% [markdown]
# ## Countries

# %%
list(inbound['Country Name'])
# Out:
# ['Aruba',
#  'Afghanistan',
#  'Angola',
#  'Albania',
#  'Andorra',
#  'Arab World',
#  'United Arab Emirates',
#  'Argentina',
#  'Armenia',
#  'American Samoa',
#  'Antigua and Barbuda',
#  'Australia',
#  'Austria',
#  'Azerbaijan',
#  'Burundi',
#  'Belgium',
#  'Benin',
#  'Burkina Faso',
#  'Bangladesh',
#  'Bulgaria',
#  'Bahrain',
#  'Bahamas, The',
#  'Bosnia and Herzegovina',
#  'Belarus',
#  'Belize',
#  'Bermuda',
#  'Bolivia',
#  'Brazil',
#  'Barbados',
#  'Brunei Darussalam',
#  'Bhutan',
#  'Botswana',
#  'Central African Republic',
#  'Canada',
#  'Central Europe and the Baltics',
#  'Switzerland',
#  'Channel Islands',
#  'Chile',
#  'China',
#  "Cote d'Ivoire",
#  'Cameroon',
#  'Congo, Dem. Rep.',
#  'Congo, Rep.',
#  'Colombia',
#  'Comoros',
#  'Cabo Verde',
#  'Costa Rica',
#  'Caribbean small states',
#  'Cuba',
#  'Curacao',
#  'Cayman Islands',
#  'Cyprus',
#  'Czech Republic',
#  'Germany',
#  'Djibouti',
#  'Dominica',
#  'Denmark',
# ...

# %%
# i kept the islands, Hong Kong, colonies, Macao, North Macedonia, Northern Mariana Islands, West Bank and Gaza
# French Polynesia
# Lao PDR is Laos or what?
regions = ['Arab World', 
           'Central Europe and the Baltics', 
           'Caribbean small states', 
           'East Asia & Pacific (excluding high income)', 
           'Early-demographic dividend', 
           'East Asia & Pacific', 
           'Europe & Central Asia (excluding high income)', 
           'Europe & Central Asia', 
           'Euro area', 
           'European Union', 
           'Fragile and conflict affected situations',
           'High income', 
           'Heavily indebted poor countries (HIPC)', 
           'IBRD only', 
           'IDA & IBRD total', 
           'IDA total', 
           'IDA blend', 
           'IDA only', 
           'Not classified', 
           'Latin America & Caribbean (excluding high income)', 
           'Latin America & Caribbean',
           'Least developed countries: UN classification',  
           'Low income', 'Lower middle income', 'Low & middle income', 
           'Late-demographic dividend', 'Middle East & North Africa', 'Middle income', 
           'Middle East & North Africa (excluding high income)', 'North America', 
           'OECD members', 'Other small states', 'Pre-demographic dividend', 'Pacific island small states', 
           'Post-demographic dividend', 'South Asia', 'Sub-Saharan Africa (excluding high income)', 
           'Small states', 'East Asia & Pacific (IDA & IBRD countries)', 
           'Europe & Central Asia (IDA & IBRD countries)', 
           'Latin America & the Caribbean (IDA & IBRD countries)', 
           'Middle East & North Africa (IDA & IBRD countries)', 
           'South Asia (IDA & IBRD)', 'Sub-Saharan Africa (IDA & IBRD countries)', 
           'Upper middle income', 'World']

# %%
# filter out regions
outbound = outbound[outbound['Country Name'].isin(regions) == False]  
expenditures = expenditures[expenditures['Country Name'].isin(regions) == False]
print(outbound.shape, expenditures.shape)
# Out:
# (218, 26) (218, 26)

# %% [markdown]
# ## Populations data

# %%
population = pd.read_csv('./data/API_SP.POP.TOTL_DS2_en_csv_v2_2445260.csv', skiprows=4)
print(population.shape)
population.head()
# Out:
# (264, 66)
#   Country Name Country Code     Indicator Name Indicator Code       1960  \
# 0        Aruba          ABW  Population, total    SP.POP.TOTL    54211.0
# 1  Afghanistan          AFG  Population, total    SP.POP.TOTL  8996973.0
# 2       Angola          AGO  Population, total    SP.POP.TOTL  5454933.0
# 3      Albania          ALB  Population, total    SP.POP.TOTL  1608800.0
# 4      Andorra          AND  Population, total    SP.POP.TOTL    13411.0
#
#         1961       1962       1963       1964       1965  ...        2012  \
# 0    55438.0    56225.0    56695.0    57032.0    57360.0  ...    102560.0
# 1  9169410.0  9351441.0  9543205.0  9744781.0  9956320.0  ...  31161376.0
# 2  5531472.0  5608539.0  5679458.0  5735044.0  5770570.0  ...  25107931.0
# 3  1659800.0  1711319.0  1762621.0  1814135.0  1864791.0  ...   2900401.0
# 4    14375.0    15370.0    16412.0    17469.0    18549.0  ...     82427.0
#
# ...

# %%
# we only need 1995-2018
population.drop(useless_cols, axis='columns', inplace=True)

# drop regions
population = population[population['Country Name'].isin(regions) == False]
print(population.shape)
population.head()
# Out:
# (218, 27)
#   Country Name Country Code        1995        1996        1997        1998  \
# 0        Aruba          ABW     80324.0     83200.0     85451.0     87277.0
# 1  Afghanistan          AFG  18110657.0  18853437.0  19357126.0  19737765.0
# 2       Angola          AGO  13945206.0  14400719.0  14871570.0  15359601.0
# 3      Albania          ALB   3187784.0   3168033.0   3148281.0   3128530.0
# 4      Andorra          AND     63850.0     64360.0     64327.0     64142.0
#
#          1999        2000        2001        2002  ...        2010  \
# 0     89005.0     90853.0     92898.0     94992.0  ...    101669.0
# 1  20170844.0  20779953.0  21606988.0  22600770.0  ...  29185507.0
# 2  15866869.0  16395473.0  16945753.0  17519417.0  ...  23356246.0
# 3   3108778.0   3089027.0   3060173.0   3051010.0  ...   2913021.0
# 4     64370.0     65390.0     67341.0     70049.0  ...     84449.0
#
#          2011        2012        2013        2014        2015        2016  \
# ...

# %% [markdown]
# ## Departures per capita

# %%
dep_per_capita = pd.merge(outbound, population, on='Country Code', suffixes=('_dep', '_pop'))
print(dep_per_capita.shape)
dep_per_capita.head()
# Out:
# (218, 52)
#   Country Name_dep Country Code  1995_dep  1996_dep  1997_dep  1998_dep  \
# 0            Aruba          ABW       NaN       NaN       NaN       NaN
# 1      Afghanistan          AFG       NaN       NaN       NaN       NaN
# 2           Angola          AGO    3000.0    3000.0       NaN       NaN
# 3          Albania          ALB       NaN       NaN       NaN       NaN
# 4          Andorra          AND       NaN       NaN       NaN       NaN
#
#    1999_dep  2000_dep  2001_dep   2002_dep  ...    2010_pop    2011_pop  \
# 0       NaN       NaN       NaN        NaN  ...    101669.0    102046.0
# 1       NaN       NaN       NaN        NaN  ...  29185507.0  30117413.0
# 2       NaN       NaN       NaN        NaN  ...  23356246.0  24220661.0
# 3       NaN       NaN  955000.0  1303000.0  ...   2913021.0   2905195.0
# 4       NaN       NaN       NaN        NaN  ...     84449.0     83747.0
#
#      2012_pop    2013_pop    2014_pop    2015_pop    2016_pop    2017_pop  \
# ...

# %%
for year in range(1995, 2019):
    dep = str(year) + '_dep'
    pop = str(year) + '_pop'
    dep_per_capita[str(year)] = dep_per_capita[dep]/dep_per_capita[pop]
#     dep_per_capita.drop([dep, pop], axis='columns', inplace=True)
dep_per_capita.head()
# Out:
#   Country Name_dep Country Code  1995_dep  1996_dep  1997_dep  1998_dep  \
# 0            Aruba          ABW       NaN       NaN       NaN       NaN
# 1      Afghanistan          AFG       NaN       NaN       NaN       NaN
# 2           Angola          AGO    3000.0    3000.0       NaN       NaN
# 3          Albania          ALB       NaN       NaN       NaN       NaN
# 4          Andorra          AND       NaN       NaN       NaN       NaN
#
#    1999_dep  2000_dep  2001_dep   2002_dep  ...      2009      2010      2011  \
# 0       NaN       NaN       NaN        NaN  ...       NaN       NaN       NaN
# 1       NaN       NaN       NaN        NaN  ...       NaN       NaN       NaN
# 2       NaN       NaN       NaN        NaN  ...       NaN       NaN       NaN
# 3       NaN       NaN  955000.0  1303000.0  ...  1.162759  1.181934  1.418149
# 4       NaN       NaN       NaN        NaN  ...       NaN       NaN       NaN
#
# ...

# %%
dep_per_capita.drop(['Unnamed: 65', 'Country Name_dep'], axis='columns', inplace = True)

# %%
dep_per_capita.rename(columns = {'Country Name_pop': 'Country Name'}, inplace=True)
dep_per_capita.head()
# Out:
#   Country Code  1995_dep  1996_dep  1997_dep  1998_dep  1999_dep  2000_dep  \
# 0          ABW       NaN       NaN       NaN       NaN       NaN       NaN
# 1          AFG       NaN       NaN       NaN       NaN       NaN       NaN
# 2          AGO    3000.0    3000.0       NaN       NaN       NaN       NaN
# 3          ALB       NaN       NaN       NaN       NaN       NaN       NaN
# 4          AND       NaN       NaN       NaN       NaN       NaN       NaN
#
#    2001_dep   2002_dep   2003_dep  ...      2009      2010      2011  \
# 0       NaN        NaN        NaN  ...       NaN       NaN       NaN
# 1       NaN        NaN        NaN  ...       NaN       NaN       NaN
# 2       NaN        NaN        NaN  ...       NaN       NaN       NaN
# 3  955000.0  1303000.0  1350000.0  ...  1.162759  1.181934  1.418149
# 4       NaN        NaN        NaN  ...       NaN       NaN       NaN
#
#        2012      2013      2014      2015      2016      2017      2018
# ...

# %% [markdown]
# ## Expenditures per departure

# %%
exp_per_dep = pd.merge(outbound, expenditures, on='Country Code', suffixes=('_dep', '_exp'))
exp_per_dep.head()
# Out:
#   Country Name_dep Country Code  1995_dep  1996_dep  1997_dep  1998_dep  \
# 0            Aruba          ABW       NaN       NaN       NaN       NaN
# 1      Afghanistan          AFG       NaN       NaN       NaN       NaN
# 2           Angola          AGO    3000.0    3000.0       NaN       NaN
# 3          Albania          ALB       NaN       NaN       NaN       NaN
# 4          Andorra          AND       NaN       NaN       NaN       NaN
#
#    1999_dep  2000_dep  2001_dep   2002_dep  ...      2009_exp      2010_exp  \
# 0       NaN       NaN       NaN        NaN  ...  2.640000e+08  2.610000e+08
# 1       NaN       NaN       NaN        NaN  ...  7.000000e+07  1.060000e+08
# 2       NaN       NaN       NaN        NaN  ...  2.700000e+08  2.750000e+08
# 3       NaN       NaN  955000.0  1303000.0  ...  1.692000e+09  1.452000e+09
# 4       NaN       NaN       NaN        NaN  ...           NaN           NaN
#
#        2011_exp      2012_exp      2013_exp      2014_exp      2015_exp  \
# ...

# %%
for year in range(1995, 2019):
    dep = str(year) + '_dep'
    exp = str(year) + '_exp'
    exp_per_dep[str(year)] = exp_per_dep[dep]/exp_per_dep[exp]
#     exp_per_dep.drop([dep, exp], axis='columns', inplace=True)
exp_per_dep.head()
# Out:
#   Country Name_dep Country Code  1995_dep  1996_dep  1997_dep  1998_dep  \
# 0            Aruba          ABW       NaN       NaN       NaN       NaN
# 1      Afghanistan          AFG       NaN       NaN       NaN       NaN
# 2           Angola          AGO    3000.0    3000.0       NaN       NaN
# 3          Albania          ALB       NaN       NaN       NaN       NaN
# 4          Andorra          AND       NaN       NaN       NaN       NaN
#
#    1999_dep  2000_dep  2001_dep   2002_dep  ...      2009      2010      2011  \
# 0       NaN       NaN       NaN        NaN  ...       NaN       NaN       NaN
# 1       NaN       NaN       NaN        NaN  ...       NaN       NaN       NaN
# 2       NaN       NaN       NaN        NaN  ...       NaN       NaN       NaN
# 3       NaN       NaN  955000.0  1303000.0  ...  0.002012  0.002371  0.002457
# 4       NaN       NaN       NaN        NaN  ...       NaN       NaN       NaN
#
# ...

# %%
exp_per_dep.drop(['Country Name_dep'], axis='columns', inplace = True)
dep_per_capita.rename(columns = {'Country Name_exp': 'Country Name'}, inplace=True)
dep_per_capita.head()
# Out:
#   Country Code  1995_dep  1996_dep  1997_dep  1998_dep  1999_dep  2000_dep  \
# 0          ABW       NaN       NaN       NaN       NaN       NaN       NaN
# 1          AFG       NaN       NaN       NaN       NaN       NaN       NaN
# 2          AGO    3000.0    3000.0       NaN       NaN       NaN       NaN
# 3          ALB       NaN       NaN       NaN       NaN       NaN       NaN
# 4          AND       NaN       NaN       NaN       NaN       NaN       NaN
#
#    2001_dep   2002_dep   2003_dep  ...      2009      2010      2011  \
# 0       NaN        NaN        NaN  ...       NaN       NaN       NaN
# 1       NaN        NaN        NaN  ...       NaN       NaN       NaN
# 2       NaN        NaN        NaN  ...       NaN       NaN       NaN
# 3  955000.0  1303000.0  1350000.0  ...  1.162759  1.181934  1.418149
# 4       NaN        NaN        NaN  ...       NaN       NaN       NaN
#
#        2012      2013      2014      2015      2016      2017      2018
# ...

# %%
def rename_cols(df):
#     for year in range(1995, 2019):
#         df.rename(columns={str(year) : '_' + str(year)}, inplace=True)
    df.rename(columns={'Country Code': 'CountryCode', 'Country Name': 'CountryName'}, inplace=True)

# %%
rename_cols(outbound)
rename_cols(expenditures)
rename_cols(population)
rename_cols(dep_per_capita)
rename_cols(exp_per_dep)

# outbound.set_index('CountryCode', inplace=True)
# expenditures.set_index('CountryCode', inplace=True)
# population.set_index('CountryCode', inplace=True)
# dep_per_capita.set_index('CountryCode', inplace=True)
# exp_per_dep.set_index('CountryCode', inplace=True)

# %%
dep_per_capita.head()
# Out:
#   CountryCode  1995_dep  1996_dep  1997_dep  1998_dep  1999_dep  2000_dep  \
# 0         ABW       NaN       NaN       NaN       NaN       NaN       NaN
# 1         AFG       NaN       NaN       NaN       NaN       NaN       NaN
# 2         AGO    3000.0    3000.0       NaN       NaN       NaN       NaN
# 3         ALB       NaN       NaN       NaN       NaN       NaN       NaN
# 4         AND       NaN       NaN       NaN       NaN       NaN       NaN
#
#    2001_dep   2002_dep   2003_dep  ...      2009      2010      2011  \
# 0       NaN        NaN        NaN  ...       NaN       NaN       NaN
# 1       NaN        NaN        NaN  ...       NaN       NaN       NaN
# 2       NaN        NaN        NaN  ...       NaN       NaN       NaN
# 3  955000.0  1303000.0  1350000.0  ...  1.162759  1.181934  1.418149
# 4       NaN        NaN        NaN  ...       NaN       NaN       NaN
#
#        2012      2013      2014      2015      2016      2017      2018
# ...

# %% [markdown]
# ## Country Codes
# amCharts package uses 2-letter codes to identify the countries => need to add these codes to the datasets.
# Data [source](https://www.kaggle.com/juanumusic/countries-iso-codes?select=wikipedia-iso-country-codes.csv)

# %%
codes = pd.read_csv('./data/wikipedia-iso-country-codes.csv')
print(codes.shape)
codes.head()
# Out:
# (246, 5)
#   English short name lower case Alpha-2 code Alpha-3 code  Numeric code  \
# 0                   Afghanistan           AF          AFG             4
# 1                 Åland Islands           AX          ALA           248
# 2                       Albania           AL          ALB             8
# 3                       Algeria           DZ          DZA            12
# 4                American Samoa           AS          ASM            16
#
#       ISO 3166-2
# 0  ISO 3166-2:AF
# 1  ISO 3166-2:AX
# 2  ISO 3166-2:AL
# 3  ISO 3166-2:DZ
# 4  ISO 3166-2:AS

# %%
codes = codes[['Alpha-2 code', 'Alpha-3 code']]
codes.rename(columns={'Alpha-2 code': 'CountryCode2', 'Alpha-3 code': 'CountryCode'}, inplace=True)

# %%
dep_per_capita = pd.merge(dep_per_capita, codes, on='CountryCode')
dep_per_capita.head()
# Out:
#   CountryCode  1995_dep  1996_dep  1997_dep  1998_dep  1999_dep  2000_dep  \
# 0         ABW       NaN       NaN       NaN       NaN       NaN       NaN
# 1         AFG       NaN       NaN       NaN       NaN       NaN       NaN
# 2         AGO    3000.0    3000.0       NaN       NaN       NaN       NaN
# 3         ALB       NaN       NaN       NaN       NaN       NaN       NaN
# 4         AND       NaN       NaN       NaN       NaN       NaN       NaN
#
#    2001_dep   2002_dep   2003_dep  ...      2010      2011      2012  \
# 0       NaN        NaN        NaN  ...       NaN       NaN       NaN
# 1       NaN        NaN        NaN  ...       NaN       NaN       NaN
# 2       NaN        NaN        NaN  ...       NaN       NaN       NaN
# 3  955000.0  1303000.0  1350000.0  ...  1.181934  1.418149  1.364984
# 4       NaN        NaN        NaN  ...       NaN       NaN       NaN
#
#        2013      2014      2015      2016      2017      2018  CountryCode2
# ...

# %%
dep_per_capita.shape
# Out:
# (212, 75)

# %% [markdown]
# ## Continents
# Map every country to a corresponding continent for the bubble plot and line chart visualisations

# %%
continents = pd.read_csv('./data/countryContinent.csv', encoding = "ISO-8859-1")
continents.head()
# Out:
#           country code_2 code_3  country_code     iso_3166_2 continent  \
# 0     Afghanistan     AF    AFG             4  ISO 3166-2:AF      Asia
# 1   Åland Islands     AX    ALA           248  ISO 3166-2:AX    Europe
# 2         Albania     AL    ALB             8  ISO 3166-2:AL    Europe
# 3         Algeria     DZ    DZA            12  ISO 3166-2:DZ    Africa
# 4  American Samoa     AS    ASM            16  ISO 3166-2:AS   Oceania
#
#         sub_region  region_code  sub_region_code
# 0    Southern Asia        142.0             34.0
# 1  Northern Europe        150.0            154.0
# 2  Southern Europe        150.0             39.0
# 3  Northern Africa          2.0             15.0
# 4        Polynesia          9.0             61.0

# %%
continents['continent'].unique()
# Out:
# array(['Asia', 'Europe', 'Africa', 'Oceania', 'Americas', nan],
#       dtype=object)

# %%
continents[continents['continent'].isnull()]
# Out:
#                                           country code_2 code_3  country_code  \
# 8                                      Antarctica     AQ    ATA            10
# 30                                  Bouvet Island     BV    BVT            74
# 32                 British Indian Ocean Territory     IO    IOT            86
# 46                               Christmas Island     CX    CXR           162
# 47                        Cocos (Keeling) Islands     CC    CCK           166
# 78                    French Southern Territories     TF    ATF           260
# 96              Heard Island and McDonald Islands     HM    HMD           334
# 206  South Georgia and the South Sandwich Islands     GS    SGS           239
# 236          United States Minor Outlying Islands     UM    UMI           581
#
#         iso_3166_2 continent sub_region  region_code  sub_region_code
# 8    ISO 3166-2:AQ       NaN        NaN          NaN              NaN
# ...

# %%
continents = continents[['code_3', 'continent']]
continents.rename(columns={'code_3': 'CountryCode', 'continent': 'Continent'}, inplace=True)

# %%
dep_per_capita = pd.merge(dep_per_capita, continents, on='CountryCode')
dep_per_capita.head()
# Out:
#   CountryCode  1995_dep  1996_dep  1997_dep  1998_dep  1999_dep  2000_dep  \
# 0         ABW       NaN       NaN       NaN       NaN       NaN       NaN
# 1         AFG       NaN       NaN       NaN       NaN       NaN       NaN
# 2         AGO    3000.0    3000.0       NaN       NaN       NaN       NaN
# 3         ALB       NaN       NaN       NaN       NaN       NaN       NaN
# 4         AND       NaN       NaN       NaN       NaN       NaN       NaN
#
#    2001_dep   2002_dep   2003_dep  ...      2011      2012      2013  \
# 0       NaN        NaN        NaN  ...       NaN       NaN       NaN
# 1       NaN        NaN        NaN  ...       NaN       NaN       NaN
# 2       NaN        NaN        NaN  ...       NaN       NaN       NaN
# 3  955000.0  1303000.0  1350000.0  ...  1.418149  1.364984  1.356779
# 4       NaN        NaN        NaN  ...       NaN       NaN       NaN
#
#        2014      2015      2016      2017      2018  CountryCode2  Continent
# ...

# %%
print(dep_per_capita.shape)
dep_per_capita[dep_per_capita['Continent'].isnull()]
# Out:
# (212, 76)
# Empty DataFrame
# Columns: [CountryCode, 1995_dep, 1996_dep, 1997_dep, 1998_dep, 1999_dep, 2000_dep, 2001_dep, 2002_dep, 2003_dep, 2004_dep, 2005_dep, 2006_dep, 2007_dep, 2008_dep, 2009_dep, 2010_dep, 2011_dep, 2012_dep, 2013_dep, 2014_dep, 2015_dep, 2016_dep, 2017_dep, 2018_dep, CountryName, 1995_pop, 1996_pop, 1997_pop, 1998_pop, 1999_pop, 2000_pop, 2001_pop, 2002_pop, 2003_pop, 2004_pop, 2005_pop, 2006_pop, 2007_pop, 2008_pop, 2009_pop, 2010_pop, 2011_pop, 2012_pop, 2013_pop, 2014_pop, 2015_pop, 2016_pop, 2017_pop, 2018_pop, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, CountryCode2, Continent]
# Index: []
#
# [0 rows x 76 columns]

# %% [markdown]
# ## Dataset containing all data
# Year-by-year and country-by country population, departures, expenditures, departures per capita, continent, country names and country codes (2- and 3-letter codes)

# %%
all_data = (pd.merge(dep_per_capita, expenditures, on='CountryCode', suffixes=('_dpc', '_exp'))
            .drop(['CountryName_dpc'], axis='columns')
            .rename(columns = {'CountryName_exp': 'CountryName'}))

# %%
all_data.head()
# Out:
#   CountryCode  1995_dep  1996_dep  1997_dep  1998_dep  1999_dep  2000_dep  \
# 0         ABW       NaN       NaN       NaN       NaN       NaN       NaN
# 1         AFG       NaN       NaN       NaN       NaN       NaN       NaN
# 2         AGO    3000.0    3000.0       NaN       NaN       NaN       NaN
# 3         ALB       NaN       NaN       NaN       NaN       NaN       NaN
# 4         AND       NaN       NaN       NaN       NaN       NaN       NaN
#
#    2001_dep   2002_dep   2003_dep  ...      2009_exp      2010_exp  \
# 0       NaN        NaN        NaN  ...  2.640000e+08  2.610000e+08
# 1       NaN        NaN        NaN  ...  7.000000e+07  1.060000e+08
# 2       NaN        NaN        NaN  ...  2.700000e+08  2.750000e+08
# 3  955000.0  1303000.0  1350000.0  ...  1.692000e+09  1.452000e+09
# 4       NaN        NaN        NaN  ...           NaN           NaN
#
#        2011_exp      2012_exp      2013_exp      2014_exp      2015_exp  \
# ...

# %%
all_data.shape
# Out:
# (212, 100)

# %%
list(all_data.columns)
# Out:
# ['CountryCode',
#  '1995_dep',
#  '1996_dep',
#  '1997_dep',
#  '1998_dep',
#  '1999_dep',
#  '2000_dep',
#  '2001_dep',
#  '2002_dep',
#  '2003_dep',
#  '2004_dep',
#  '2005_dep',
#  '2006_dep',
#  '2007_dep',
#  '2008_dep',
#  '2009_dep',
#  '2010_dep',
#  '2011_dep',
#  '2012_dep',
#  '2013_dep',
#  '2014_dep',
#  '2015_dep',
#  '2016_dep',
#  '2017_dep',
#  '2018_dep',
#  '1995_pop',
#  '1996_pop',
#  '1997_pop',
#  '1998_pop',
#  '1999_pop',
#  '2000_pop',
#  '2001_pop',
#  '2002_pop',
#  '2003_pop',
#  '2004_pop',
#  '2005_pop',
#  '2006_pop',
#  '2007_pop',
#  '2008_pop',
#  '2009_pop',
#  '2010_pop',
#  '2011_pop',
#  '2012_pop',
#  '2013_pop',
#  '2014_pop',
#  '2015_pop',
#  '2016_pop',
#  '2017_pop',
#  '2018_pop',
#  '1995_dpc',
#  '1996_dpc',
#  '1997_dpc',
#  '1998_dpc',
#  '1999_dpc',
#  '2000_dpc',
#  '2001_dpc',
#  '2002_dpc',
#  '2003_dpc',
#  '2004_dpc',
#  '2005_dpc',
#  '2006_dpc',
#  '2007_dpc',
#  '2008_dpc',
#  '2009_dpc',
#  '2010_dpc',
#  '2011_dpc',
# ...

# %% [markdown]
# ## Save clean data

# %%
assets = '../website/src/assets/data/'
# # outbound
# outbound.to_csv('./data/departures.csv')
# outbound.to_csv(assets + 'departures.csv')
# # expenditures
# expenditures.to_csv('./data/expenditures.csv')
# expenditures.to_csv(assets + 'expenditures.csv')
# # population
# population.to_csv('./data/population.csv')
# population.to_csv(assets + 'population.csv')
# # departures per capita
# dep_per_capita.to_csv(assets + 'dep_per_capita.csv')
# # expenditures per departure
# exp_per_dep.to_csv(assets + 'exp_per_dep.csv')
# all data together
all_data.to_csv('./data/full_dataset.csv')
all_data.to_csv(assets + 'full_dataset.csv')
